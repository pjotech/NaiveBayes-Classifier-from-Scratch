# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.font_manager
from sklearn.model_selection import train_test_split

# %%
#to handle the whitespaces in the columns use sep and encoding as below

# %%
data=pd.read_csv('C:\s3\Pattern\proj\diabetes.csv', encoding='utf-8-sig', sep='\s*,\s*', engine='python')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_train, df_test = train_test_split(data,  test_size=0.3)
print (df_train.shape)
print (df_test.shape)
# Out:
# (537, 9)
# (231, 9)

# %%
df_train.reset_index()
# Out:
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      449            0      120             74             18       63  30.5
# 1      572            3      111             58             31       44  29.5
# 2      190            3      111             62              0        0  22.6
# 3      245            9      184             85             15        0  30.0
# 4      296            2      146             70             38      360  28.0
# 5      443            8      108             70              0        0  30.5
# 6      184            4      141             74              0        0  27.6
# 7      120            0      162             76             56      100  53.2
# 8      122            2      107             74             30      100  33.6
# 9      694            2       90             60              0        0  23.5
# 10     725            4      112             78             40        0  39.4
# ...

# %%
grouped = df_train.groupby('Outcome')


df_mean = grouped.mean()
df_mean
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness    Insulin  \
# Outcome
# 0           3.394886  110.642045      68.676136      19.701705  67.789773
# 1           4.870270  139.313514      71.789189      22.832432  99.854054
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.610795                  0.434827  31.139205
# 1        35.066486                  0.512070  37.200000

# %%
grouped.std()
# Out:
#          Pregnancies    Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.091257  25.604537      18.474367      14.768072   99.880191
# 1           3.660071  32.120512      20.269218      17.586402  133.684514
#
#               BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        7.706500                  0.316459  11.174118
# 1        7.577495                  0.325798  10.582389

# %%
for region, df_region in df_train.groupby('Outcome'):
    j = df_region.get_group(key).reset_index(drop=True)
    dictionary['Outcome'] = j.at[0, 'Outcome']
    dictionary['Outcome']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-0c8ebcb72fa0> in <module>
#       1 for region, df_region in df_train.groupby('Outcome'):
# ----> 2     j = df_region.get_group(key).reset_index(drop=True)
#       3     dictionary['Outcome'] = j.at[0, 'Outcome']
#       4     dictionary['Outcome']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'
